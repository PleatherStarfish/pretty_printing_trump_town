# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
staff = pd.read_csv('staffers.csv', sep=',', index_col='id', escapechar="\\")
outorgs = pd.read_csv('outside_government_positions.csv', sep=',', index_col='id', escapechar="\\")

# %%
data = outorgs.join(staff, on='staffer_id', lsuffix ="_out")

# %%
data_out = data[['slug', 'agency_slug', 'position_title_1','position_title_2','position_title_3','staffer_id','start_date','end_date','agency_id','grade_level','linkedin_url','organization_name','organization_type','position_held','from_date','to_date','organization_slug']]

# %%
d = data_out.copy()

# %%
data.to_csv('outfile1.csv')

# %%
columns_to_fix = ['start_date', 'end_date', 'from_date', 'to_date']
for column in columns_to_fix:
    outdate = []
    for item in d['g_start_date'].iteritems():
        try:
            item = datetime.datetime.strptime(str(item[1]), '%Y-%m-%d')
            item = item.timestamp()
            outdate.append(item)
        except ValueError as exc:
            print(item)
            outdate.append(item[1])
    d[column] = pd.Series(outdate)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'g_start_date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-386ea85fd210> in <module>()
#       2 for column in columns_to_fix:
#       3     outdate = []
# ----> 4     for item in d['g_start_date'].iteritems():
#       5         try:
#       6             item = datetime.datetime.strptime(str(item[1]), '%Y-%m-%d')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'g_start_date'

# %%
d.head()
# Out:
#                   slug                    agency_slug  \
# id
# 2198  william-j-briggs  small-business-administration
# 2        diane-l-cullo                    agriculture
# 3        diane-l-cullo                    agriculture
# 4      william-northey                    agriculture
# 5      william-northey                    agriculture
#
#                                        position_title_1 position_title_2  \
# id
# 2198                                     Senior Advisor              NaN
# 2     Special Assistant, Office of the Assistant Sec...              NaN
# 3     Special Assistant, Office of the Assistant Sec...              NaN
# 4     Under Secretary for Farm and Foreign Agricultu...              NaN
# 5     Under Secretary for Farm and Foreign Agricultu...              NaN
#
#      position_title_3  staffer_id  start_date end_date  agency_id grade_level  \
# id
# 2198              NaN        1830  2017-11-13      NaN         32    $131,767
# 2                 NaN         293  2017-03-07      NaN          1    $131,767
# 3                 NaN         293  2017-03-07      NaN          1    $131,767
# 4                 NaN         974         NaN      NaN          1         NaN
# 5                 NaN         974         NaN      NaN          1         NaN
#
#                                  linkedin_url  \
# id
# 2198                                      NaN
# 2     https://www.linkedin.com/in/dianecullo/
# 3     https://www.linkedin.com/in/dianecullo/
# 4                                         NaN
# 5                                         NaN
#
#                                       organization_name  \
# id
# 2198  Property Casualty Insurers Association of America
# 2                            Wegmans Food Markets, Inc.
# 3                                    DLC Communications
# 4                                         State of Iowa
# 5                                       WM Northey Farm
#
#                                       organization_type  \
# id
# 2198                                  Trade Association
# 2                                           Corporation
# 3     Self-employed Communication s Consulting Organ...
# 4                                            Government
# 5                                   Sole Proprietorship
#
#                        position_held   from_date     to_date  \
# id
# 2198  Director, Political Engagement  2013-09-03  2017-11-03
# 2           Service Desk Team leader  2015-02-15  2016-08-16
# 3                          Principal  2005-01-16         NaN
# 4      Iowa Secretary of Agriculture  2007-01-16         NaN
# 5                    Sole Proprietor  1981-05-16         NaN
#
#                                       organization_slug
# id
# 2198  property-casualty-insurers-association-of-america
# 2                              wegmans-food-markets-inc
# 3                                    dlc-communications
# 4                                         state-of-iowa
# 5                                       wm-northey-farm

# %% [markdown]
# Okay, now we parse all of this into a dictionary which we will output in the following as JSON:
#
#     {
#       "agency_id": {
#         "staffer_id": {
#             "position_title_1": string,
#             "position_title_2": string,
#             "position_title_3": string,
#             "start_date": int,
#             "end_date": int,
#             "organization_slug": {
#                 "organization_type": string,
#                 "organization_name": string,
#                 "position_held": string,
#                 "from_date": int,
#                 "to_date": int
#             }
#           },
#         "slug": string,
#         "linkedin_url": string
#         },
#       "agency_slug": string
#     }

# %%
import json
import csv

# This dictionary is used to make column indices a little more readable.
column = {
          'id': 0, 'slug': 1, 'agency_slug': 2, 
          'position_title_1': 3, 'position_title_2': 4, 
          'position_title_3': 5, 'staffer_id': 6, 
          'start_date': 7, 'end_date': 8, 'agency_id': 9, 
          'grade_level': 10, 'linkedin_url': 11, 
          'organization_name': 12, 'organization_type': 13, 
          'position_held': 14, 'from_date': 15, 'to_date':16, 
          'organization_slug': 17
         }

data_dict = {}
staffer_dic = {}

        
with open('outfile1.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    
    for row in readCSV:
        if row[column['staffer_id']] in staffer_dic:
            pass
        else:
            staffer_dic[ row[ column['agency_id']] ] = { }
    
    for row in readCSV:
        if row[column['agency_id']] in data_dict:
            pass
        else:
            data_dict[ row[ column['agency_id']] ] = { }
            
        
print(data_dict)
# Out:
# {}

# %%
with open('outfile1.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
